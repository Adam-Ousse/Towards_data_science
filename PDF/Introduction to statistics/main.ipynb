# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
##bernoulli distribution
from scipy.stats import binom
coin_flips=binom.rvs(10,0.5,size=1000000)
plt.hist(coin_flips)
plt.show()
# Out:
# 0.000977

# %%
# print(binom.cdf(2,10,0.5))
print(binom.pmf(2,10,0.5))
print(len([i for i in coin_flips if i==2])/1000000)
# Out:
# 0.04394531250000005
# 0.044076
